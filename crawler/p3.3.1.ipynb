# %%
import requests as req


url="https://www.pcschoolonline.com.tw/2017/student_02_ClassSchedule.aspx"
head={
    'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}
respon=req.get(url).text

print(respon)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head><meta charset="utf-8" /><meta name="viewport" content="width=device-width,initial-scale=1.0,user-scalable=0" /><meta http-equiv="X-UA-Compatible" content="IE=edge" /><meta name="format-detection" content="telephone=no" /><title>
# 	巨匠直播教學｜線上課程-真人直播互動：Python程式、室內設計、AutoCAD、資安網管、視覺設計
# </title><meta name="keywords" content="巨匠電腦,巨匠直播教學,電腦補習班,學電腦,電腦課程,巨匠電腦評價,在職進修,線上教學" /><meta name="description" content="巨匠直播專業教學，學習超簡單！提供各種巨匠專業課程學習及評價，專業課程包含Python、AI程式設計、手機app、工業設計、室內設計及證照考試等，是學專業課程最佳選擇。" /><meta id="ctl00_og_description" name="og:description" content="巨匠直播專業教學，學習超簡單！提供各種巨匠專業課程學習及評價，專業課程包含Python、AI程式設計、手機app、工業設計、室內設計及證照考試等，是學專業課程最佳選擇。" /><meta id="ctl00_og_image" property="og:image" /><meta id="ctl00_og_title" property="og:title" content="巨匠直播教學｜線上課程-真人直播互動：Python程式、室內設計、AutoCAD、資安網管、視覺設計" /><meta property="og:type" content="website" /><meta property="og:url" /><meta property="og:site_name" content="巨匠直播教學-電腦補習班,學電腦" />
#     <!--[if lt IE 10]>
#           <script>
#               alert('親愛的同學您好，您使用的瀏覽器為IE8/9，目前本網站已不支援IE9(含)以下的版本，請使用IE9以後的版本或其他瀏覽器。');
#               location.href='https://www.google.com.tw/chrome/browser/desktop/index.html';
#               //location.href='/index.aspx';
#           </script>
#         <![endif]-->
#     <!-- PcschoolOnline Activity Page 2020 : Header & Footer Style -->
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/meyer-reset/2.0/reset.css" rel="stylesheet" /><link href="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.5.2/css/bootstrap.css" rel="stylesheet" /><link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.5.0/css/font-awesome.min.css" /><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.css" integrity="sha256-UK1EiopXIL+KVhfbFa8xrmAWPeBjMVdvYMYkTAEv/HI=" crossorigin="anonymous" /><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick-theme.min.css" integrity="sha256-4hqlsNP9KM6+2eA8VUT0kk4RsMRTeS7QGHIM+MZ5sLY=" crossorigin="anonymous" /><link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.13.1/css/all.min.css" rel="stylesheet" /><link href="/2017/css/showFrame.css?V=20210708" rel="stylesheet" /><link href="2017/css/pcschoolonline-activity-2021.css?V=2021111001" rel="stylesheet" /><link href="2017/css/pcschoolonline-activity-responsive-2021.css" rel="stylesheet" /><link href="/js/slick/slick/slick.min.css" rel="stylesheet" /><link href="/js/animate.min.css" rel="stylesheet" type="text/css" /><link href="/js/Magnific-Popup/dist/magnific-popup.min.css" rel="stylesheet" /><link href="/2017/css/style.css?version=001" rel="stylesheet" /><link href="/2017/defaultMaster.css?V=202000601" rel="stylesheet" />
#
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.5.1/jquery.min.js" crossorigin="anonymous"></script>
#
#
#
#
#     <script>
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date(); a = s.createElement(o),
#                 m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', 'https://www.google-analytics.com/analytics.js', 'ga');
#
#         ga('create', 'UA-89035906-1', 'auto');
#         ga('send', 'pageview');
#
#         $(document).ready(function () {
#             $('#Member_menu').on('show.bs.dropdown', function () {
#                 $.ajax({
#                     type: "POST",
#                     url: "/ws2016.asmx/getLoginStatus",
#                     contentType: "application/json; charset=utf-8",
#                     dataType: "json",
#                     success: function (data, status) {
#                         var dataAry = $.parseJSON(data.d);
#                         if (dataAry.length === 0) {
#                             $('#Member_menu').addClass('show');
#                             $('#Member_menu>.dropdown-menu').addClass('open');
#                             $('#Member_menu>.dropdown-menu').addClass('show');
#                         } else {
#                             var d = dataAry[0];
#
#                             if (d.islogin === 1) {
#                                 $('#Member_menu').addClass('show');
#                                 $('#Member_menu>.dropdown-menu').addClass('open');
#                                 $('#Member_menu>.dropdown-menu').addClass('show');
#                             } else {
#                                 setTimeout(function () {
#                                     //alert("學員身分專用，請先登入會員");
#                                     var url = "/2017/login.aspx?ReturnUrl=/2017/student_02_ClassSchedule.aspx";
#                                     $(".show_frame iframe").attr("src", url);
#                                     $(".show_frame").show();
#                                 }, 300);
#                             }
#                         }
#                     },
#                     error: function (jqXHR, textStatus, errorThrown) {
#                         logger(jqXHR);
#                         logger(textStatus);
#                         logger(errorThrown);
#                         alert("系統發生錯誤，請重試...");
#                         //$('#Member_menu').attr('class', 'dropdown open');
#                     }
#                 });
#                 return false;
#             });
#         });
#
#
#     </script>
# <!-- 2021/03/08 Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-KG435LW');</script>
# <!-- End Google Tag Manager -->
#
# </head>
# <body>
#     <!--2021/03/08  Google Tag Manager (noscript) -->
#     <noscript>
#         <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KG435LW"
#             height="0" width="0" style="display: none; visibility: hidden"></iframe>
#     </noscript>
#     <!-- End Google Tag Manager (noscript) -->
#
#     <form name="aspnetForm" method="post" action="./default.aspx?ReturnUrl=%2f2017%2fstudent_02_ClassSchedule.aspx" id="aspnetForm">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="..." />
#
#
# <script src="Scripts/WebForms/MsAjax/MicrosoftAjax.js" type="text/javascript"></script>
# <script type="text/javascript">
# //<![CDATA[
# if (typeof(Sys) === 'undefined') throw new Error('ASP.NET Ajax client-side framework failed to load.');
# //]]>
# </script>
#
# <input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="CA0B0334" />
# <input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="/wEdAAKoarDQQgghWgJySNRm4ZUGwimKzVT6zJvH7+tjWNmHGBOUnNntu1W/jquP67n1Iodn8PhHhRUThUCSKRJTleNk" />
#
#
#     <!-- PcschoolOnline Activity Page 2021 : Header Start -->
#     <div class="pcschoolonline-activity-2021">
#         <nav class="navbar navbar-expand-lg">
#             <div class="container">
#                 <a class="navbar-brand m-logo" href="https://www.pcschoolonline.com.tw/">
#                     <img src="/2017/images/pcschoolonline-activity-logo.png" class="pcschoolonline-logo"
#                         title="巨匠直播教學-電腦補習班,學電腦" alt="巨匠直播教學">
#                 </a>
#                 <button class="navbar-toggler" type="button" data-toggle="collapse"
#                     data-target="#navbarSupportedContent" aria-controls="navbarSupportedContent" aria-expanded="false"
#                     aria-label="Toggle navigation">
#                     <i class="fas fa-bars"></i>
#                 </button>
#                 <div class="collapse navbar-collapse" id="navbarSupportedContent">
#                     <ul class="navbar-nav mr-auto" id="pcschoolonline-navMain">
#                         <li class="nav-item my-auto">
#                             <a class="nav-link" href="/2017/inqClass.aspx">開課查詢</a>
#                         </li>
#                         <li class="nav-item dropdown  my-auto">
#                             <a class="nav-link dropdown-toggle " href="#" id="navbarDropdown-1" role="button"
#                                 data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                                 課程總覽
#                             </a>
#                             <div class="dropdown-menu open rounded-0" aria-labelledby="navbarDropdown">
#                                 <div class="container">
#                                     <ul class="pcschoolonline-navItems">
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass2">工業設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass3">建築室內設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass1">視覺設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass10">網頁設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass4">3D多媒體動畫</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass11">影視特效</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass6">程式/資料庫</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass12">AI程式設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass5">手機APP設計</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass7">資安網路管理</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass8">辦公室應用</a></li>
#
#                                             <li><a href="/2017/introcourse.aspx?courseid=NEWClass9">認證輔導</a></li>
#
#
#                                     </ul>
#                                 </div>
#                             </div>
#                         </li>
#                         <li class="nav-item my-auto">
#                             <a class="nav-link" href="/teacher">專業師資</a>
#                         </li>
#                         <li class="nav-item my-auto">
#                             <a class="nav-link" href="/2017/newbie1.aspx">新手專區</a>
#                         </li>
#                         <li class="nav-item dropdown  my-auto" id="Member_menu">
#                             <a class="nav-link dropdown-toggle" href="#" id="navbarDropdown-2" role="button"
#                                 data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                                 學員專區
#                             </a>
#                             <div class="dropdown-menu rounded-0" aria-labelledby="navbarDropdown">
#                                 <div class="container">
#                                     <ul class="pcschoolonline-navItems">
#                                         <li><a href="/2017/student_02_ClassSchedule.aspx">我的課表</a></li>
#                                         <li><a href="/2017/student_04_FileDownload.aspx">課程檔案下載</a></li>
#                                         <li><a href="/2017/student_13_VideoRecordReport.aspx">課程觀看記錄</a></li>
#                                         <li><a href="/2017/student_06_Advisory.aspx">學習諮詢</a></li>
#                                         <li><a href="/2017/inqclass2.aspx">直播教學課程劃位</a></li>
#                                         <li><a href="/2017/cancelclasslist.aspx">取消劃位</a></li>
#                                         <li><a href="/2017/student_03_PersonalData.aspx">個資維護</a></li>
#                                         <li><a href="/2017/student_12_PurchaseHistory.aspx">購買記錄</a></li>
#                                         <li><a href="/2017/student_08_CardDots.aspx">上課權益查詢</a></li>
#                                         <li><a href="/2017/student_10_CardTrs.aspx">點數卡產品兌換</a></li>
#                                            <li><a href="/2017/student_11_ITCheck.aspx">申請線上設備檢測</a></li>
#
#                                         <li><a href="/2017/student_07_FAQ.aspx">常見問題</a></li>
#
#                                         <li>
#                                             <a id="ctl00_ucHeader3_btnLogout" href="javascript:__doPostBack(&#39;ctl00$ucHeader3$btnLogout&#39;,&#39;&#39;)">登出</a>
#                                         </li>
#                                     </ul>
#                                 </div>
#                             </div>
#                         </li>
#                         <li class="nav-item my-auto">
#                             <a class="nav-link" href="/2017/student_01_Announcement.aspx">最新消息</a>
#                         </li>
#                         <li class="nav-item d-block d-sm-none">
#                             <ul class="toolbar2">
#                                 <li><a href="https://www.abconline.com.tw/t01_login_new.aspx" target="_blank"
#                                         class="iconLinker">
#                                         <img src="/2017/images/topbtn_teacher.png" width="45" height="45"></a></li>
#                                 <li><a href="https://www.worker360.com.tw/" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/WORKER360ICON.PNG" width="45" height="45"></a></li>
#                                 <li><a href="/blog" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/blogicon2.png" width="45" height="45"></a></li>
#                                 <li><a href="https://www.youtube.com/gjunchannel" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/youtubeicon.png" width="45" height="45"></a></li>
#                             </ul>
#                         </li>
#                         <li class="nav-item text-right d-none d-xl-block">
#                             <ul class="toolbar2">
#                                 <li><a href="https://www.abconline.com.tw/t01_login_new.aspx" target="_blank"
#                                         class="iconLinker">
#                                         <img src="/2017/images/topbtn_teacher.png" width="45" height="45"></a></li>
#                                 <li><a href="https://www.worker360.com.tw/" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/WORKER360ICON.PNG" width="45" height="45"></a></li>
#                                 <li><a href="/blog" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/blogicon2.png" width="45" height="45"></a></li>
#                                 <li><a href="https://www.youtube.com/gjunchannel" target="_blank" class="iconLinker">
#                                         <img src="/2017/images/youtubeicon.png" width="45" height="45"></a></li>
#                             </ul>
#                         </li>
#                     </ul>
#                 </div>
#             </div>
#         </nav>
#         <div style="display: none;">
#             <p id="c_id"></p>
#             <p id="std_no"></p>
#         </div>
#     </div>
#
#
#
#         <!-- PcschoolOnline Activity Top : banner Start -->
#
#     <div id="myCarousel" class="carousel slide" data-ride="carousel">
#         <ol class="carousel-indicators">
#
#
#                   <li data-target="#myCarousel" data-slide-to="0" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="1" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="2" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="3" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="4" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="5" ></li>
#
#                   <li data-target="#myCarousel" data-slide-to="6" ></li>
#
#
#
#
#
#
#
#         </ol>
#         <div class="carousel-inner" role="listbox">
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/activity/gen/luckysummer/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_51re.webp"   alt='' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_51re_m.webp"   alt=''   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/activity/it-network-security/misclass/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_52.webp"   alt='雲端網路管理課程' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_52_m.webp"   alt='雲端網路管理課程'   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/activity/boarding/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_43.jpg"   alt='' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_43_m.jpg"   alt=''   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/activity/gen/facetoface/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_46.jpg"   alt='' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_46_m.jpg"   alt=''   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/activity/interior-practice/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/96-200699b.jpg"   alt='' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/96-200699mb.jpg"   alt=''   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/Activity/python-begin/index.html?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_24.jpg"   alt='Python易學好用' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/TopAD_24_m.jpg"   alt='Python易學好用'   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#                 <div class="carousel-item ">
#                      <a href="https://www.pcschoolonline.com.tw/Activity/online-apcs/default.aspx?fromto=99237009" target='_blank'>
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/96-200698b.jpg"   alt='' class="img-fluid d-none d-md-block w-100"  />
#                         <img src="//www.pcschoolonline.com.tw/updimg/TopAD/96-200698mb.jpg"   alt=''   class="img-fluid d-md-none w-100"/>
#                          </a>
#                 </div>
#
#
#
#
#
#
#         </div>
#         <a class="carousel-control-prev" href="#myCarousel" role="button" data-slide="prev">
#             <span class="carousel-control-prev-icon" aria-hidden="true"></span>
#             <span class="sr-only">Previous</span>
#         </a>
#         <a class="carousel-control-next" href="#myCarousel" role="button" data-slide="next">
#             <span class="carousel-control-next-icon" aria-hidden="true"></span>
#             <span class="sr-only">Next</span>
#         </a>
#     </div>
#
#
#     <script>
#         $(function () {
#
#         });
#     </script>
# <script>
#     $(function () {
#         $('.carousel-item').eq(0).addClass("active");
#         $('.carousel-indicators li').eq(0).addClass("active");
#
#         //$('[data-ride="carousel"]').swiperight(function () {
#         //    $(this).carousel('prev');
#         //});
#         //$('[data-ride="carousel"]').swipeleft(function () {
#         //    $(this).carousel('next');
#         //});
#
#     });
# </script>
#
#     <!-- PcschoolOnline Activity Top : banner End -->
#
#     <!-- PcschoolOnline Activity Intro Start -->
#     <div class="pcschoolonline-intro">
#
#
#         <div class="container-one">
#             <div class="row">
#                 <div class="subtitle">巨匠直播教學課程</div>
#                 <div class="introBox">
#                     <div class="row">
#
#                                 <div class="col-md-12">
#                                     <a href="https://www.pcschoolonline.com.tw/activity/boarding/index.html?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/ITboarding.jpg" class="card-img-top" alt="IT人才培訓專機起飛">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">IT人才培訓課程</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>Cisco系列課程va系列課程                            產學就業率屢破新高
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#                                 <div class="col-md-12">
#                                     <a href="https://www.pcschoolonline.com.tw/Activity/live-streaming/index.html?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/職訓宅急便.jpg" class="card-img-top" alt="熱門課程馬上領 - 巨匠直播教學課程">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">熱門課程馬上領</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>電商接案接不完                                    爆發遊戲元宇宙
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#                                 <div class="col-md-12">
#                                     <a href="https://www.pcschoolonline.com.tw/Activity/microsoft-office/default.aspx?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/辦公室.png" class="card-img-top" alt="Office實務應用 - 巨匠直播教學課程">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">Office實務應用</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>MOS微軟國際認證                                  Word論文與企劃書編排技巧
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#                                 <div class="col-md-12">
#                                     <a href="https://www.pcschoolonline.com.tw/Activity/python-begin/index.html?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/AIPYTHON2.jpg" class="card-img-top" alt="PYTHON x AI程式新手-巨匠直播教學課程">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">PYTHON x AI程式新手</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>人工智慧整合開發                                   PYTHON程式分階學習
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#                                 <div class="col-md-12">
#                                     <a href="https://www.pcschoolonline.com.tw/activity/uiuxdesign/index.html?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/uiux.jpg" class="card-img-top" alt="設計行銷必上UI/UX - 巨匠直播教學課程">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">設計行銷必上UI/UX</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>超越市面理論課                                    使用者介面UI
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#                                 <div class="col-md-12">
#                                     <a href="https://pcschoolonline.com.tw/activity/game-metaverse/index.html?fromto=99244003" target="_blank">
#                                     <div class="card"
#                                         style="background-color: transparent; border: 0px solid rgba(0, 0, 0, 0.125);">
#                                         <img src="//www.pcschoolonline.com.tw/updimg/ClassType/20180307/遊戲設計.png" class="card-img-top" alt="遊戲設計 - 巨匠直播教學課程">
#                                         <div class="card-body">
#                                             <h5 class="card-title"
#                                                 style="font-size: 1.3125rem; color: #e47611; text-align: center;">元宇宙遊戲設計</h5>
#                                             <p class="card-text" style="color: #333333; font-size: 1rem;">
# <br/>>>索取免費試聽發                                  遊戲原畫設計
#                                             </p>
#                                         </div>
#                                     </div>
#                                         </a>
#                                 </div>
#
#
#
#
#
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#
#
#
#
#
# <script>
#         $(document).ready(function () {
#             $(".introBox .row").slick({
#                 dots: false,
#                 infinite: true,
#                 arrows: true,
#                 autoplay: true,
#                 slidesToShow: 3,
#                 slidesPerRow: 1,
#                 responsive: [{
#                         breakpoint: 1200,
#                         settings: {
#                             slidesToShow: 3
#                         }
#                     },
#                     {
#                         breakpoint: 900,
#                         settings: {
#                             slidesToShow: 3
#                         }
#                     },
#                     {
#                         breakpoint: 768,
#                         settings: {
#                             slidesToShow: 2,
#                         }
#                     },
#                     {
#                         breakpoint: 480,
#                         settings: {
#                             slidesToShow: 1
#                         }
#                     }
#                 ]
#             });
#         });
# </script>
#
#
#         <div class="container-two">
#             <div class="row">
#                 <div class="subtitle">影片介紹</div>
#                 <div class="col-md-4 col-12 mb-1" style="color: #333333;font-size: 1.125rem;">
#                     <span style="font-size: 1.3125rem !important;">
#                         全新定義學習新世紀</span><br>
#                     跨越平台 真人實境 名師親授
#                 </div>
#                 <div class="col-md-8 col-12 mb-4" style="color: #333333;font-size: 1rem;text-align: justify;">
#                     科技分秒演進，一定要用快又有效的學習方式，掌握最新知識與技術！
#                     巨匠電腦深耕資訊教育30年，是全國最大原廠授權教育中心，引領台灣資訊培訓與時俱進，零時差與國際接軌；繼領先同業推出「虛實整合雙軌培訓」，成為業界標竿，更推出全新「線上真人電腦教學」跨平台使用聯網載具就能上課，與名師面對面即時互動，讓您身歷其境、更有效率！
#                 </div>
#                 <div class="introBox">
#                     <div class="row">
#
#
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/76Aq9h7VxSs?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="AI世代搶手的工程師必學，Python程式設計" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/76Aq9h7VxSs/0.jpg" class="img-fluid center-block"
#                                     alt="AI世代搶手的工程師必學，Python程式設計" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        AI世代搶手的工程師必學，Python程式設計
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/bc3bYrEe8qY?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="影視特效設計課程介紹" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/bc3bYrEe8qY/0.jpg" class="img-fluid center-block"
#                                     alt="影視特效設計課程介紹" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        影視特效設計課程介紹
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/tfxev-8Ivfo?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="遊戲動畫設計課程介紹" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/tfxev-8Ivfo/0.jpg" class="img-fluid center-block"
#                                     alt="遊戲動畫設計課程介紹" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        遊戲動畫設計課程介紹
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/ACOGVj4En0k?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="包裝創意，維持創作的戰鬥力！" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/ACOGVj4En0k/0.jpg" class="img-fluid center-block"
#                                     alt="包裝創意，維持創作的戰鬥力！" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        包裝創意，維持創作的戰鬥力！
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/XeL9vzcZTtI?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="職場致勝簡報術" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/XeL9vzcZTtI/0.jpg" class="img-fluid center-block"
#                                     alt="職場致勝簡報術" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        職場致勝簡報術
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/v-dBPq9n2S4?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="CAD基本圖學" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/v-dBPq9n2S4/0.jpg" class="img-fluid center-block"
#                                     alt="CAD基本圖學" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        CAD基本圖學
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/ASiHc7gs9mA?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="Word論文與企劃書編排技巧" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/ASiHc7gs9mA/0.jpg" class="img-fluid center-block"
#                                     alt="Word論文與企劃書編排技巧" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        Word論文與企劃書編排技巧
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/9O1ayVVTmS0?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="Python程式設計" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/9O1ayVVTmS0/0.jpg" class="img-fluid center-block"
#                                     alt="Python程式設計" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        Python程式設計
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="col-md-12">
#                             <div class="card"
#                                 style="background-color: transparent;border: 0px solid rgba(0, 0, 0, 0.125);position: relative;overflow: hidden;">
#
#                                 <img src="/2017/images/video_icon.png"  data-navurl="//www.youtube.com/embed/Y4mF8tJGdzQ?rel=0&showinfo=0&iv_load_policy=3" class="linker img-fluid center-block" alt="播放"
#                                     style="position: absolute;top: 0;left: 0;margin: 30% 42%;z-index: 99;"></img>
#                                  <img src="/2017/images/cardbox.png" class="img-fluid center-block" alt="產品設計實務班" style="position: absolute;top: 0;left: 0;">
#                                 <img src="https://i3.ytimg.com/vi/Y4mF8tJGdzQ/0.jpg" class="img-fluid center-block"
#                                     alt="產品設計實務班" style="top: 0;left: 0;"></img>
#                                 <div class="card-body">
#                                     <h5 class="card-title" style="font-size: 1rem;color:#e47611;text-align: center; ">
#                                        產品設計實務班
#                                     </h5>
#                                 </div>
#                             </div>
#                         </div>
#
#
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#
#
#
#
#
# <div class="movie" style="display:none;">
#     <div class="container">
#         <div class="panel2Wrapper">
#             <h2 class="panel2Header purple1 ">
#                 影片介紹
#             </h2>
#         </div>
#         <div class="row">
#             <div class="col-md-12">
#                 <h1>全新定義 學習新世紀<small style="color: #eb6100; margin: auto 10px">跨越平台，真人實境，名師親授！</small></h1>
#                 <h4 style="line-height: 30px">科技分秒演進，一定要用快又有效的學習方式，掌握最新知識與技術！<br>
#                     巨匠電腦深耕資訊教育30年，是全國最大原廠授權教育中心，引領台灣資訊培訓與時俱進，零時差與國際接軌；繼領先同業推出「虛實整合雙軌培訓」，成為業界標竿，更推出全新「線上真人電腦教學」跨平台使用聯網載具就能上課，與名師面對面即時互動，讓您身歷其境、更有效率！
#                 </h4>
#             </div>
#             <div style="clear: both; position: relative;">
#                 <div class="col-md-12 carousel-introVideo">
#
#                             <div class="col-md-4 col-sm-12" style="margin: 25px 0; position: relative;">
#                                 <div class="linker center-block text-center" data-navurl="//www.youtube.com/embed/76Aq9h7VxSs?rel=0&showinfo=0&iv_load_policy=3">
#                                     <img src="https://i3.ytimg.com/vi/76Aq9h7VxSs/0.jpg" class="img-responsive center-block" alt="AI世代搶手的工程師必學，Python程式設計"></img>
#                                 </div>
#                                 <div class="clearfix" style="position:absolute;float:right;bottom:1px;right:20px;z-index:99;">
#                                     <span class="glyphicon glyphicon-play" style="color: red; font-size: 24px;"></span>
#                                 </div>
#                             </div>
#
#                             <div class="col-md-4 col-sm-12" style="margin: 25px 0; position: relative;">
#                                 <div class="linker center-block text-center" data-navurl="//www.youtube.com/embed/bc3bYrEe8qY?rel=0&showinfo=0&iv_load_policy=3">
#                                     <img src="https://i3.ytimg.com/vi/bc3bYrEe8qY/0.jpg" class="img-responsive center-block" alt="影視特效設計課程介紹"></img>
#                                 </div>
#                                 <div class="clearfix" style="position:absolute;float:right;bottom:1px;right:20px;z-index:99;">
#                                     <span class="glyphicon glyphicon-play" style="color: red; font-size: 24px;"></span>
#                                 </div>
#                             </div>
#
#                             <div class="col-md-4 col-sm-12" style="margin: 25px 0; position: relative;">
#                                 <div class="linker center-block text-center" data-navurl="//www.youtube.com/embed/tfxev-8Ivfo?rel=0&showinfo=0&iv_load_policy=3">
#                                     <img src="https://i3.ytimg.com/vi/tfxev-8Ivfo/0.jpg" class="img-responsive center-block" alt="遊戲動畫設計課程介紹"></img>
#                                 </div>
#                                 <div class="clearfix" style="position:absolute;float:right;bottom:1px;right:20px;z-index:99;">
#                                     <span class="glyphicon glyphicon-play" style="color: red; font-size: 24px;"></span>
#                                 </div>
#                             </div>
#
#                             <div class="col-md-4 col-sm-12" style="margin: 25px 0; position: relative;">
#                                 <div class="linker center-block text-center" data-navurl="//www.youtube.com/embed/ACOGVj4En0k?rel=0&showinfo=0&iv_load_policy=3">
#                                     <img src="https://i3.ytimg.com/vi/ACOGVj4En0k/0.jpg" class="img-responsive center-block" alt="包裝創意，維持創作的戰鬥力！"></img>
#                                 </div>
#                                 <div class="clearfix" style="position:absolute;float:right;bottom:1px;right:20px;z-index:99;">
#                                     <span class="glyphicon glyphicon-play" style="color: red; font-size: 24px;"></span>
#                                 </div>
#                             </div>
#
#                             <div class="col-md-4 col-sm-12" style="margin: 25px 0; position: relative;">
#                                 <div class="linker center-block text-center" data-navurl="//www.youtube.com/embed/XeL9vzcZTtI?rel=0&showinfo=0&iv_load_policy=3">
# ...
#                                                 aria-expanded="false" aria-controls="collapseTwo"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 巨匠美語
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseTwo" aria-labelledby="headingTwo" data-parent="#accordionExample"
#                                         class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.soeasyedu.com.tw/branch-school"
#                                                 target="_blank">全國分校</a>
#                                             <a href="https://www.soeasyedu.com.tw/courses" target="_blank">全國課表</a>
#                                             <a href="https://www.soeasyedu.com.tw/mobile-learning"
#                                                 target="_blank">蜂美語APP</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#
#                                 <!-- Accordion item 3 -->
#                                 <div class="card">
#                                     <div id="headingThree" class="card-header bg-white border-0">
#                                         <h2 class="mb-0">
#                                             <button type="button" data-toggle="collapse" data-target="#collapseThree"
#                                                 aria-expanded="false" aria-controls="collapseThree"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 巨匠東大日語
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseThree" aria-labelledby="headingThree"
#                                         data-parent="#accordionExample" class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.onejapan.com.tw/branch-school" target="_blank">全國分校</a>
#                                             <a href="https://www.onejapan.com.tw/courses" target="_blank">全國課表</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#
#                                 <!-- Accordion item 4 -->
#                                 <div class="card">
#                                     <div id="headingFour" class="card-header bg-white border-0">
#                                         <h2 class="mb-0">
#                                             <button type="button" data-toggle="collapse" data-target="#collapseFour"
#                                                 aria-expanded="false" aria-controls="collapseFour"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 巨匠雲端
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseFour" aria-labelledby="headingFour" data-parent="#accordionExample"
#                                         class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.abconline.com.tw/" target="_blank">巨匠線上真人</a>
#                                             <a href="https://www.abconline.com.tw/2020/course/course.aspx?lang=us"
#                                                 target="_blank">美語線上真人</a>
#                                             <a href="https://www.abconline.com.tw/2020/course/course.aspx?lang=jp"
#                                                 target="_blank">日語線上真人</a>
#                                             <a href="https://www.abconline.com.tw/2020/course/course.aspx?lang=kr"
#                                                 target="_blank">韓語線上真人</a>
#                                             <a href="https://www.abconline.com.tw/2020/course/course.aspx?lang=sp"
#                                                 target="_blank">西班牙語線上真人</a>
#                                             <a href="https://www.wincenter.com.tw/" target="_blank">巨匠狀元王</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#
#                                 <!-- Accordion item 5 -->
#                                 <div class="card">
#                                     <div id="headingFive" class="card-header bg-white border-0">
#                                         <h2 class="mb-0">
#                                             <button type="button" data-toggle="collapse" data-target="#collapseFive"
#                                                 aria-expanded="false" aria-controls="collapseFive"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 巨匠數位學院
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseFive" aria-labelledby="headingFive" data-parent="#accordionExample"
#                                         class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.pcschool.tv/default.aspx" target="_blank">電腦數位學院</a>
#                                             <a href="https://www.pcschool.tv/soeasyedu/" target="_blank">美日語數位學院</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#
#                                 <!-- Accordion item 6 -->
#                                 <div class="card">
#                                     <div id="headingSix" class="card-header bg-white border-0">
#                                         <h2 class="mb-0">
#                                             <button type="button" data-toggle="collapse" data-target="#collapseSix"
#                                                 aria-expanded="false" aria-controls="collapseSix"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 社群
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseSix" aria-labelledby="headingSix" data-parent="#accordionExample"
#                                         class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.facebook.com/pccoding/" target="_blank">就醬玩電腦</a>
#                                             <a href="https://www.facebook.com/link.pcschool/" target="_blank">校園福利社</a>
#                                             <a href="https://www.facebook.com/94Creative/"
#                                                 target="_blank">94Creative</a>
#                                             <a href="https://www.facebook.com/pccoding/" target="_blank">全民Coding</a>
#                                             <a href="https://www.facebook.com/woke360/" target="_blank">窩課360</a>
#                                             <a href="https://www.facebook.com/gjunsoeasy/" target="_blank">就愛嗑英文吐司</a>
#                                             <a href="https://www.youtube.com/channel/UCM1dmadr5oSlMTdmdDRZcoA"
#                                                 target="_blank">巨匠YouTube</a>
#                                             <a href="line://ti/p/@jox8901a" target="_blank">Line官方帳號</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#
#                                 <!-- Accordion item 7 -->
#                                 <div class="card">
#                                     <div id="headingSeven" class="card-header bg-white border-0">
#                                         <h2 class="mb-0">
#                                             <button type="button" data-toggle="collapse" data-target="#collapseSeven"
#                                                 aria-expanded="false" aria-controls="collapseSeven"
#                                                 class="btn btn-link collapsed text-dark font-weight-bold text-uppercase collapsible-link">
#                                                 其他
#                                             </button>
#                                         </h2>
#                                     </div>
#                                     <div id="collapseSeven" aria-labelledby="headingSeven"
#                                         data-parent="#accordionExample" class="collapse">
#                                         <div class="card-body">
#                                             <a href="https://www.pcschool.com.tw/member/Message.html"
#                                                 target="_blank">隱私暨個資保護聲明</a>
#                                             <a href="https://www.pcschool.com.tw/aboutGjun/about.aspx"
#                                                 target="_blank">關於巨匠</a>
#                                             <a href="https://www.pcschoolonline.com.tw/2017/newbie4.aspx"
#                                                 target="_blank">體驗專區</a>
#                                             <a href="https://www.pcschoolonline.com.tw/2017/Contract/"
#                                                 target="_blank">契約簽署</a>
#                                             <a href="https://www.pcschoolonline.com.tw/2017/student_06_Advisory.aspx"
#                                                 target="_blank">學習諮詢</a>
#                                             <a href="https://www.pcschool.com.tw/2017/prevent-fraud.html"
#                                                 target="_blank">防詐騙提醒</a>
#                                             <a href="https://itunes.apple.com/tw/app/%E5%B7%A8%E5%8C%A0%E9%9B%BB%E8%85%A6%E5%AD%B8%E5%93%A1%E6%9C%8D%E5%8B%99/id1297108141?mt=8"
#                                                 target="_blank">學員APP (iOS)</a>
#                                             <a href="https://play.google.com/store/apps/details?id=com.gjun.itstudentservice&hl="
#                                                 target="_blank">學員APP (Android)</a>
#                                         </div>
#                                     </div>
#                                 </div><!-- End -->
#                             </div>
#                         </div>
#                         <div class="col-lg-4 col-12">
#                             <div class="callService">
#                                 <h4>
#                                     電話服務時間 │ 週一至週五 13:30~21:00
#                                 </h4>
#
#                                 <h3>
#                                     <span>服務專線 │ </span>
#                                     <font style="color: rgba(238, 120, 30, 1.0);">02-2311-5668</font><br>
#                                     <span>(市話撥打)</span>
#                                     <font style="color: rgba(238, 120, 30, 1.0);">0800-388-668</font>
#                                 </h3>
#                                 <h3>
#                                     <span>客服信箱 │</span>
#                                      <a href="mailto:PConlineHelp@pcschool.com.tw" style="display:initial !important;">PConlineHelp@pcschool.com.tw</a>
#                                 </h3>
#                                 <h3>
#                                     <span>防疫期間，用line服務更快喔！ </span>
#                                     <a href="https://lin.ee/lA7p4NQ"><img height="36" border="0" src="/2017/images/serviceByLine.png" alt="防疫期間，用line服務更快喔！"></a>
#                                 </h3>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#             <div class="footer-info">
#                 <div class="container">
#                     <div class="footer-infoBox">
#                         <div class="row">
#                             <div class="col-md-6 col-12 my-auto">
#                                 <img src="https://www.pcschoolonline.com.tw/2017/images/logo_gjun.png" alt=""
#                                     class="pcschoolonline-footer-logo">
#                             </div>
#                             <div class="col-md-6 col-12">
#                                 <div class="footer-copyright">
#                                     巨匠電腦股份有限公司 版權所有<br>
#                                     Coypright 2022 Gjun Information Co.,Ltd.
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </footer>
#     </div>
#     <!-- PcschoolOnline Activity Page 2020 : Footer End -->
#
#
#         <div class="show_frame">
#             <iframe src="/2017/login.aspx?ReturnUrl=/2017/student_02_ClassSchedule.aspx" allowtransparency="true" border="0" style="border: 0;"></iframe>
#         </div>
#     </form>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/4.5.2/js/bootstrap.js"
#         crossorigin="anonymous"></script>
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.js"></script>
#     <script src="/2017/js/pcschoolonline-activity-2021.js"></script>
#     <script src="/2017/js/pcschool-webbase.js" type="text/javascript"></script>
#
#         <script src="/js/slick/slick/slick.min.js"></script>
#      <script src="/js/Magnific-Popup/dist/jquery.magnific-popup.min.js"></script>
#      <script src="/2017/defaultMaster.js?V=001"></script>
#
#
#     <script type="text/javascript">
#
#         $(document).ready(function () {
#             $(".supplyBox .row").slick({
#                 dots: false,
#                 infinite: true,
#                 arrows: true,
#                 autoplay: true,
#                 slidesToShow: 4,
#                 slidesPerRow: 1,
#                 responsive: [{
#                         breakpoint: 1200,
#                         settings: {
#                             slidesToShow: 4
#                         }
#                     },
#                     {
#                         breakpoint: 900,
#                         settings: {
#                             slidesToShow: 3
#                         }
#                     },
#                     {
#                         breakpoint: 768,
#                         settings: {
#                             slidesToShow: 2,
#                         }
#                     },
#                     {
#                         breakpoint: 480,
#                         settings: {
#                             slidesToShow: 1
#                         }
#                     }
#                 ]
#             });
#         });
#     </script>
#     <script>
#         function goLineBind() {
#             var url = "/LineBind.aspx";
#             $(".show_frame iframe").attr("src", url);
#             $(".show_frame").show();
#         }
#     </script>
#
#
# </body>
# </html>

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Obtaining dependency information for requests from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/a4/65/057bf29660aae6ade0816457f8db4e749e5c0bfa2366eb5f67db9912fa4c/charset_normalizer-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading charset_normalizer-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 3.6 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/9b/81/62fd61001fa4b9d0df6e31d47ff49cfa9de4af03adecf339c7bc30656b37/urllib3-2.0.4-py3-none-any.whl.metadata
#   Downloading urllib3-2.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/4c/dd/2234eab22353ffc7d94e8d13177aaa050113286e93e7b40eae01fbf7c3d9/certifi-2023.7.22-py3-none-any.whl.metadata
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 1.7 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.4 MB/s eta 0:00:00
# Downloading charset_normalizer-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.8/201.8 kB 11.1 MB/s eta 0:00:00
# Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 8.3 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2023.7.22 charset-normalizer-3.2.0 idna-3.4 requests-2.31.0 urllib3-2.0.4
